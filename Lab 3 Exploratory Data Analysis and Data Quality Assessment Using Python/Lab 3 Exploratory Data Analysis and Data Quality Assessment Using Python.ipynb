# %% [markdown]
# # Lab 3: Exploratory Data Analysis and Data Quality Assessment Using Python

# %% [markdown]
# ### Data Quality Checks
# 1. How many rows and columns are in the dataset?
# 2. What are the data types of each column?
# 3. Are there any missing values?
# 4. Are there duplicate records?
#
# ### Employee Overview
# 5. How many employees are there in the dataset?
# 6. How many departments exist in the organization?
# 7. What are the departments present in the dataset?
# 8. What is the minimum and maximum employee age?
# 9. What is the average monthly income?
# 10. What is the gender distribution of employees?
# 11. How many employees belong to each department?
# 12. How many employees have more than 10 years of experience?
# 13. How many employees have been with the company for more than 5 years?
#
# ### Department Analysis
# 14. What is the average monthly income for each department?
# 15. How many employees left the company in each department?

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('hr_analytics.csv')
df
# Out:
#      Age Attrition              Department  Gender  MonthlyIncome  \
# 0     20        No  Research & Development  Female           2116
# 1     38        No  Research & Development  Female          12195
# 2     37        No  Research & Development    Male          15426
# 3     29        No  Research & Development    Male          11916
# 4     23        No                   Sales  Female           8911
# ..   ...       ...                     ...     ...            ...
# 299   28        No  Research & Development  Female           4131
# 300   37        No                   Sales  Female          12128
# 301   49        No                   Sales    Male           6332
# 302   21        No                   Sales    Male           5903
# 303   59        No  Research & Development    Male           2478
#
#      TotalWorkingYears  YearsAtCompany
# 0                   22               0
# 1                   28               0
# 2                   26               3
# ...

# %%
df.shape
# Out:
# (304, 7)

# %%
print(df.dtypes)
# Out:
# Age                  int64
# Attrition              str
# Department             str
# Gender                 str
# MonthlyIncome        int64
# TotalWorkingYears    int64
# YearsAtCompany       int64
# dtype: object

# %%
df.isnull()
# Out:
#        Age  Attrition  Department  Gender  MonthlyIncome  TotalWorkingYears  \
# 0    False      False       False   False          False              False
# 1    False      False       False   False          False              False
# 2    False      False       False   False          False              False
# 3    False      False       False   False          False              False
# 4    False      False       False   False          False              False
# ..     ...        ...         ...     ...            ...                ...
# 299  False      False       False   False          False              False
# 300  False      False       False   False          False              False
# 301  False      False       False   False          False              False
# 302  False      False       False   False          False              False
# 303  False      False       False   False          False              False
#
#      YearsAtCompany
# 0             False
# ...

# %%
df.isnull().sum()
# Out:
# Age                  0
# Attrition            0
# Department           0
# Gender               0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 299    False
# 300     True
# 301     True
# 302     True
# 303     True
# Length: 304, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 4

# %%
len(df)
# Out:
# 304

# %%
df['Department'].nunique()
# Out:
# 3

# %%
df['Department'].unique()
# Out:
# <StringArray>
# ['Research & Development', 'Sales', 'Human Resources']
# Length: 3, dtype: str

# %%
print("Min Age:", df['Age'].min())
print("Max Age:", df['Age'].max())
# Out:
# Min Age: 18
# Max Age: 60

# %%
print(round(df['MonthlyIncome'].mean(), 2))
# Out:
# 10910.78

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      158
# Female    146
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    192
# Sales                     100
# Human Resources            12
# Name: count, dtype: int64

# %%
t = df['TotalWorkingYears'] > 10
print(t.sum())
# Out:
# 212

# %%
c = df['YearsAtCompany'] > 5
print(c.sum())
# Out:
# 165

# %%
dept_salary = df.groupby('Department')['MonthlyIncome'].mean()
dept_salary
# Out:
# Department
# Human Resources           11561.666667
# Research & Development    10712.052083
# Sales                     11214.220000
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('Department')['Attrition'].count()
# Out:
# Department
# Human Resources            12
# Research & Development    192
# Sales                     100
# Name: Attrition, dtype: int64
